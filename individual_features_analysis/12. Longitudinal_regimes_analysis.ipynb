# %% [markdown]
# # LONGITUDINAL REGIMES OF THE HUMAN GUT MICROBIOME
#
# This Jupyter Notebook contains main functions to define longitudinal regimes of the human gut microbiome

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from collections import Counter

# %% [markdown]
# ### Define longitudinal regimes

# %%
wd = './data/'

# %%
df = pd.read_csv(wd + '/ts_charactericstics_tables/LONGITUDINAL_CHARACTERISTICS_DF.csv')

male_df = pd.read_csv(wd + 'ready_files/male_rarefied_18000_interpolated_pchip.tsv', sep = '\t', index_col = [0]).T
female_df = pd.read_csv(wd + 'ready_files/female_rarefied_18000_interpolated_pchip.tsv', sep = '\t', index_col = [0]).T
donorA_df = pd.read_csv(wd + 'ready_files/donorA_rarefied_18000_interpolated_pchip.tsv', sep = '\t', index_col = [0]).T
donorB_df = pd.read_csv(wd + 'ready_files/donorB_rarefied_18000_interpolated_pchip.tsv',sep = '\t', index_col = [0]).T

def filter_dataset(data, treshold=150):
    
    df = data.iloc[:treshold]
    df_sum = df.sum().reset_index().sort_values(by = [0])
    keep_features = df_sum[df_sum[0] != 0]['index'].values
    data_filtered = df[keep_features]
    
    return data_filtered

#donorB_df = filter_dataset(donorB_df)

datasets = [male_df, female_df, donorA_df, donorB_df]
subjects = ['male', 'female', 'donorA', 'donorB']

# %%
colors = [ '#8d99ae', '#0f4c5c', '#fcca46', '#a1c181', '#e36414', '#457b9d']
regimes = ['noise', 'rare', 'stable_temporal', 'unstable_temporal', 'unstable_prevalent', 'stable_prevalent']

# %%
def conditions(s):
    if (s['prevalence'] < .1) and (s['white_noise_binary'] == 1) and (s['stationary'] == 1):
        return 'noise'
    elif (s['prevalence'] < .1) and (s['white_noise_binary'] == 0):
        return 'rare'
    elif (s['prevalence'] > .8) and (s['stationary'] == 1) and (s['white_noise_binary'] == 0):
        return 'stable_prevalent'
    elif (s['prevalence'] > .8) and (s['stationary'] == 0) and (s['white_noise_binary'] == 0):
        return 'unstable_prevalent'
    elif (s['prevalence'] < .8) and (s['prevalence'] > .1) and (s['stationary'] == 1) and (s['white_noise_binary'] == 0):
        return 'stable_temporal'
    elif (s['prevalence'] < .8) and (s['prevalence'] > .1) and (s['stationary'] == 0) and (s['white_noise_binary'] == 0):
        return 'unstable_temporal'
    else:
        return 'undefined'

df['regime'] = df.apply(conditions, axis=1)

# %%
Counter(df[df['subject'] == 'male']['regime'])
# Out:
# Counter({'unstable_temporal': 130,
#          'rare': 325,
#          'noise': 552,
#          'stable_temporal': 148,
#          'stable_prevalent': 39,
#          'unstable_prevalent': 40,
#          'undefined': 19})

# %%
Counter(df[df['subject'] == 'female']['regime'])
# Out:
# Counter({'stable_temporal': 92,
#          'noise': 222,
#          'rare': 138,
#          'stable_prevalent': 33,
#          'unstable_prevalent': 20,
#          'unstable_temporal': 39,
#          'undefined': 7})

# %%
Counter(df[df['subject'] == 'donorA']['regime'])
# Out:
# Counter({'noise': 941,
#          'stable_temporal': 95,
#          'stable_prevalent': 46,
#          'unstable_prevalent': 14,
#          'rare': 357,
#          'unstable_temporal': 51,
#          'undefined': 20})

# %%
Counter(df[df['subject'] == 'donorB']['regime'])
# Out:
# Counter({'rare': 516,
#          'stable_temporal': 147,
#          'noise': 715,
#          'unstable_prevalent': 14,
#          'undefined': 19,
#          'stable_prevalent': 12,
#          'unstable_temporal': 146})

# %% [markdown]
# ### Plot quantity of each regime

# %%
from collections import Counter
REGIME_DF = pd.DataFrame()
for i in range(0, 4):
    
    d=Counter(df[(df['subject'] == subjects[i])].regime)
    res_df = pd.DataFrame.from_dict(d, orient='index').reset_index()
    res_df.columns = ['seasonal', 'count']
    res_df = res_df.set_index('seasonal').T
    res_df['subject'] = subjects[i]
    REGIME_DF = pd.concat([REGIME_DF, res_df])
    
REGIME_DF = REGIME_DF[['noise', 'rare', 'stable_temporal', 'unstable_temporal', 'unstable_prevalent', 'stable_prevalent', 'subject']]

# %%
ax = REGIME_DF.iloc[:, :7].plot(kind='bar', stacked=True, figsize = (15, 7), width=.95, edgecolor='k', lw=.8, color = colors)#['#cccccc', '#999999', '#81b29a', '#5f797b', '#fb8500', '#219ebc'])
plt.legend(edgecolor = 'k', fontsize=18, bbox_to_anchor=(1, 1))
ax.set_xticklabels(['male', 'female', 'donorA', 'donorB'], rotation=0, fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=18)
ax.tick_params(axis='both', which='minor', labelsize=18)
ax.set_xlabel('subject', fontsize=18)
ax.set_ylabel('number of taxa', fontsize=18)
plt.title('Number of taxa in each of longitudinal regime', fontsize=24)
#ax.grid(axis='y')
plt.tight_layout()
#plt.savefig('fig5.svg', dpi=300)

# %% [markdown]
# ### Plot regimes flucturation in time

# %%
def plot_regimes(df, ftable, subject, legend=False):
    
    df = df
    ftable = ftable.reset_index().rename({'index':'feature'}, axis=1)

    merged_df = pd.merge(ftable, df[['feature', 'regime']], on = 'feature')
    merged_df = merged_df.drop('feature', axis=1).groupby(by = 'regime').sum()
    merged_df_t = merged_df.T
    rel_ab_df = merged_df_t.div(merged_df_t.sum(axis=1), axis=0)
    rel_ab_df = rel_ab_df[regimes]
    
    colors = [ '#8d99ae', '#0f4c5c', '#fcca46', '#a1c181', '#e36414', '#457b9d']
    
    rel_ab_df_rolling = rel_ab_df.transform(lambda x: x.rolling(window=3).mean()).dropna().reset_index(drop=True)


    ax = rel_ab_df.plot(kind='bar', stacked=True, width=1, edgecolor='k', lw=0, figsize = (15, 3), color=colors)
    
    if legend == True:
        
        #plt.legend(bbox_to_anchor=(1, 1.3),loc = 'upper right', title= 'REGIME', ncol=6, edgecolor='k', fontsize=14)
        #plt.rcParams['legend.title_fontsize'] = 'xx-large'
        plt.xlabel('time [days]', fontsize=18)
        ax.get_legend().remove()

    elif legend == False:   
        ax.get_legend().remove()

    plt.xticks(np.arange(0, ftable.shape[1], 100), np.arange(0, ftable.shape[1], 100))
    plt.tick_params(axis='both', which='major', labelsize=16, labelrotation = 0)
    plt.tick_params(axis='both', which='minor', labelsize=16, labelrotation = 90)
    plt.ylim([0, 1])
    plt.tight_layout()
    #plt.title(subject, fontsize=18)
    plt.savefig(f'fig{subject}.svg', dpi=300)
    plt.show()

# %%
plot_regimes(df[df['subject'] == 'male'], male_df.T, 'male', False)

# %%
plot_regimes(df[df['subject'] == 'female'], female_df.T, 'female', False)

# %%
plot_regimes(df[df['subject'] == 'donorA'], donorA_df.T, 'donorA', False)

# %%
plot_regimes(df[df['subject'] == 'donorB'], donorB_df.T, 'donorB', True)

# %% [markdown]
# ### Loading of longitudinal regimes

# %%
df['loading'] = df['PC1_loading'] + df['PC2_loading']

sns.set_style('whitegrid')
plt.figure(figsize = (18, 7))
colors = [ '#8d99ae', '#0f4c5c', '#fcca46', '#a1c181', '#e36414', '#457b9d']
c = 'k'
sns.boxplot(data=df, x = 'regime', y = 'loading', palette = colors,fliersize=0, 
            boxprops=dict(edgecolor= 'k'),
            capprops=dict(color=c),
            whiskerprops=dict(color=c),
            medianprops=dict(color=c))

sns.stripplot(data=df, x = 'regime', y = 'loading', palette = colors, s=10)
#plt.grid('x')
plt.tick_params(axis='both', which='major', labelsize=16)
plt.tick_params(axis='both', which='minor', labelsize=16)
plt.xlabel('subject', fontsize=16)
plt.ylabel('Loading', fontsize=16)
# Out:
# Text(0, 0.5, 'Loading')
